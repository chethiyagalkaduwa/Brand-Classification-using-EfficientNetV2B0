# %%
import os
import ast
import numpy as np
import pandas as pd
from PIL import Image
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import Model
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.regularizers import l2

# === CONFIG ===
LABEL_FILE = "/kaggle/input/labels/label_finalized 1.txt"
IMAGE_DIR = "/kaggle/input/train-data/Final_Data"
IMAGE_SIZE = (224, 224)
BATCH_SIZE = 16
EPOCHS_WARMUP = 5
EPOCHS_FINETUNE = 40
CLASS_INDEX_PATH = "/kaggle/working/class_indices_mobilenet.npy"

# === Load and Encode Labels ===
data = []
with open(LABEL_FILE, "r") as f:
    for line in f:
        parts = line.strip().split(None, 1)
        if len(parts) == 2:
            filename = parts[0].strip('"')
            brand = ast.literal_eval(parts[1])[0].strip().lower()
            data.append({"filename": filename, "brand": brand})

df = pd.DataFrame(data)
label_encoder = LabelEncoder()
df["label"] = label_encoder.fit_transform(df["brand"])
class_names = label_encoder.classes_
num_classes = len(class_names)
np.save(CLASS_INDEX_PATH, class_names)

# === Preprocess Images ===
def preprocess_image(image_path):
    img = Image.open(image_path).convert("RGB").resize(IMAGE_SIZE)
    return img_to_array(img) / 255.0

X = []
y = []

for _, row in tqdm(df.iterrows(), total=len(df)):
    path = os.path.join(IMAGE_DIR, row["filename"])
    if os.path.exists(path):
        try:
            X.append(preprocess_image(path))
            y.append(row["label"])
        except:
            print(f"Error loading {path}")

X = np.stack(X)
y = tf.keras.utils.to_categorical(y, num_classes=num_classes)

# === Split into Train/Val ===
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# === Compute Class Weights ===
y_labels = np.argmax(y_train, axis=1)
class_weights = compute_class_weight(class_weight="balanced", classes=np.unique(y_labels), y=y_labels)
class_weights = dict(enumerate(class_weights))

# === Data Augmentation ===
datagen = ImageDataGenerator(
    rotation_range=30,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.15,
    zoom_range=0.3,
    brightness_range=[0.7, 1.3],
    horizontal_flip=True,
    fill_mode='nearest'
)
datagen.fit(X_train)

# === Model Definition (MobileNetV2) ===
base_model = MobileNetV2(include_top=False, input_tensor=Input(shape=(224, 224, 3)), weights="imagenet")
x = GlobalAveragePooling2D()(base_model.output)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu')(x)
x = Dropout(0.5)(x)
output = Dense(num_classes, activation="softmax", kernel_regularizer=l2(1e-4))(x)
model = Model(inputs=base_model.input, outputs=output)

# === Callbacks ===
early_stop = EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=1e-6, verbose=1)

# === Warm-Up Phase ===
base_model.trainable = False
loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=loss_fn,
    metrics=["accuracy", tf.keras.metrics.TopKCategoricalAccuracy(k=3)]
)
print("🔁 Warm-up phase: training top layers only")
warmup_history = model.fit(
    datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_val, y_val),
    epochs=EPOCHS_WARMUP,
    class_weight=class_weights,
    callbacks=[early_stop, reduce_lr]
)

# === Fine-Tuning Phase ===
base_model.trainable = True
loss_fn = tf.keras.losses.CategoricalCrossentropy(label_smoothing=0.1)
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss=loss_fn,
    metrics=["accuracy", tf.keras.metrics.TopKCategoricalAccuracy(k=3)]
)

print("🎯 Fine-tuning full model")
finetune_history = model.fit(
    datagen.flow(X_train, y_train, batch_size=BATCH_SIZE),
    validation_data=(X_val, y_val),
    epochs=EPOCHS_FINETUNE,
    class_weight=class_weights,
    callbacks=[reduce_lr]
)

# === Combine History ===
def merge_history(h1, h2):
    history = {}
    for k in h1.history:
        history[k] = h1.history[k] + h2.history[k]
    return history

history = merge_history(warmup_history, finetune_history)

# === Plot Training Curves ===
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history['accuracy'], label='Train Accuracy')
plt.plot(history['val_accuracy'], label='Val Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history['loss'], label='Train Loss')
plt.plot(history['val_loss'], label='Val Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.tight_layout()
plt.savefig("mobilenet_training_plot.png")
plt.show()

# === Save Model ===
model.save("/kaggle/working/mobilenet_finetuned.h5")
print("✅ Final MobileNetV2 model saved.")
# Out:
# 100%|██████████| 2720/2720 [00:30<00:00, 89.21it/s]
# /tmp/ipykernel_31/2193409275.py:88: UserWarning: `input_shape` is undefined or non-square, or `rows` is not in [96, 128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
#   base_model = MobileNetV2(include_top=False, input_tensor=Input(shape=(224, 224, 3)), weights="imagenet")
# 🔁 Warm-up phase: training top layers only
# Epoch 1/5
# /usr/local/lib/python3.11/dist-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:122: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 39s 204ms/step - accuracy: 0.0355 - loss: 4.0762 - top_k_categorical_accuracy: 0.0917 - val_accuracy: 0.0276 - val_loss: 3.6602 - val_top_k_categorical_accuracy: 0.0901 - learning_rate: 1.0000e-04
# Epoch 2/5
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 172ms/step - accuracy: 0.0255 - loss: 3.6690 - top_k_categorical_accuracy: 0.0821 - val_accuracy: 0.0239 - val_loss: 3.6284 - val_top_k_categorical_accuracy: 0.0864 - learning_rate: 1.0000e-04
# Epoch 3/5
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 171ms/step - accuracy: 0.0219 - loss: 3.5878 - top_k_categorical_accuracy: 0.0779 - val_accuracy: 0.0129 - val_loss: 3.6169 - val_top_k_categorical_accuracy: 0.0790 - learning_rate: 1.0000e-04
# Epoch 4/5
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 171ms/step - accuracy: 0.0335 - loss: 3.5453 - top_k_categorical_accuracy: 0.1030 - val_accuracy: 0.0129 - val_loss: 3.6202 - val_top_k_categorical_accuracy: 0.0680 - learning_rate: 1.0000e-04
# Epoch 5/5
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 172ms/step - accuracy: 0.0318 - loss: 3.5463 - top_k_categorical_accuracy: 0.1036 - val_accuracy: 0.0239 - val_loss: 3.6120 - val_top_k_categorical_accuracy: 0.0790 - learning_rate: 1.0000e-04
# 🎯 Fine-tuning full model
# Epoch 1/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 83s 208ms/step - accuracy: 0.0254 - loss: 3.5716 - top_k_categorical_accuracy: 0.0763 - val_accuracy: 0.0257 - val_loss: 3.5853 - val_top_k_categorical_accuracy: 0.0864 - learning_rate: 1.0000e-05
# Epoch 2/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0309 - loss: 3.5592 - top_k_categorical_accuracy: 0.0804 - val_accuracy: 0.0312 - val_loss: 3.5744 - val_top_k_categorical_accuracy: 0.1085 - learning_rate: 1.0000e-05
# Epoch 3/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.0238 - loss: 3.5505 - top_k_categorical_accuracy: 0.0815 - val_accuracy: 0.0386 - val_loss: 3.5785 - val_top_k_categorical_accuracy: 0.1103 - learning_rate: 1.0000e-05
# Epoch 4/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 177ms/step - accuracy: 0.0266 - loss: 3.5526 - top_k_categorical_accuracy: 0.0814 - val_accuracy: 0.0349 - val_loss: 3.5890 - val_top_k_categorical_accuracy: 0.1158 - learning_rate: 1.0000e-05
# Epoch 5/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 177ms/step - accuracy: 0.0331 - loss: 3.5470 - top_k_categorical_accuracy: 0.0926 - val_accuracy: 0.0368 - val_loss: 3.5925 - val_top_k_categorical_accuracy: 0.1029 - learning_rate: 1.0000e-05
# Epoch 6/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step - accuracy: 0.0278 - loss: 3.5407 - top_k_categorical_accuracy: 0.0818
# Epoch 6: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0278 - loss: 3.5407 - top_k_categorical_accuracy: 0.0818 - val_accuracy: 0.0257 - val_loss: 3.5909 - val_top_k_categorical_accuracy: 0.0827 - learning_rate: 1.0000e-05
# Epoch 7/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.0366 - loss: 3.5311 - top_k_categorical_accuracy: 0.0986 - val_accuracy: 0.0239 - val_loss: 3.5876 - val_top_k_categorical_accuracy: 0.0956 - learning_rate: 5.0000e-06
# Epoch 8/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0281 - loss: 3.5367 - top_k_categorical_accuracy: 0.0885 - val_accuracy: 0.0423 - val_loss: 3.5839 - val_top_k_categorical_accuracy: 0.1158 - learning_rate: 5.0000e-06
# Epoch 9/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.0295 - loss: 3.5394 - top_k_categorical_accuracy: 0.1027 - val_accuracy: 0.0312 - val_loss: 3.5911 - val_top_k_categorical_accuracy: 0.1066 - learning_rate: 5.0000e-06
# Epoch 10/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.0293 - loss: 3.5268 - top_k_categorical_accuracy: 0.0946
# Epoch 10: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 177ms/step - accuracy: 0.0293 - loss: 3.5268 - top_k_categorical_accuracy: 0.0947 - val_accuracy: 0.0276 - val_loss: 3.5921 - val_top_k_categorical_accuracy: 0.1195 - learning_rate: 5.0000e-06
# Epoch 11/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0319 - loss: 3.5353 - top_k_categorical_accuracy: 0.1003 - val_accuracy: 0.0331 - val_loss: 3.5886 - val_top_k_categorical_accuracy: 0.1011 - learning_rate: 2.5000e-06
# Epoch 12/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 173ms/step - accuracy: 0.0314 - loss: 3.5256 - top_k_categorical_accuracy: 0.0970 - val_accuracy: 0.0331 - val_loss: 3.5883 - val_top_k_categorical_accuracy: 0.1029 - learning_rate: 2.5000e-06
# Epoch 13/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 173ms/step - accuracy: 0.0276 - loss: 3.5275 - top_k_categorical_accuracy: 0.0958 - val_accuracy: 0.0294 - val_loss: 3.5950 - val_top_k_categorical_accuracy: 0.1066 - learning_rate: 2.5000e-06
# Epoch 14/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.0407 - loss: 3.5287 - top_k_categorical_accuracy: 0.1065
# Epoch 14: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0407 - loss: 3.5287 - top_k_categorical_accuracy: 0.1064 - val_accuracy: 0.0331 - val_loss: 3.5983 - val_top_k_categorical_accuracy: 0.1029 - learning_rate: 2.5000e-06
# Epoch 15/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0301 - loss: 3.5267 - top_k_categorical_accuracy: 0.0940 - val_accuracy: 0.0312 - val_loss: 3.6085 - val_top_k_categorical_accuracy: 0.0938 - learning_rate: 1.2500e-06
# Epoch 16/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 173ms/step - accuracy: 0.0353 - loss: 3.5313 - top_k_categorical_accuracy: 0.1034 - val_accuracy: 0.0221 - val_loss: 3.6113 - val_top_k_categorical_accuracy: 0.0882 - learning_rate: 1.2500e-06
# Epoch 17/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0333 - loss: 3.5271 - top_k_categorical_accuracy: 0.1016 - val_accuracy: 0.0257 - val_loss: 3.6107 - val_top_k_categorical_accuracy: 0.0864 - learning_rate: 1.2500e-06
# Epoch 18/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step - accuracy: 0.0351 - loss: 3.5290 - top_k_categorical_accuracy: 0.1020
# Epoch 18: ReduceLROnPlateau reducing learning rate to 1e-06.
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0351 - loss: 3.5290 - top_k_categorical_accuracy: 0.1020 - val_accuracy: 0.0257 - val_loss: 3.6081 - val_top_k_categorical_accuracy: 0.0882 - learning_rate: 1.2500e-06
# Epoch 19/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0328 - loss: 3.5304 - top_k_categorical_accuracy: 0.0926 - val_accuracy: 0.0257 - val_loss: 3.6023 - val_top_k_categorical_accuracy: 0.0901 - learning_rate: 1.0000e-06
# Epoch 20/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0345 - loss: 3.5291 - top_k_categorical_accuracy: 0.0897 - val_accuracy: 0.0239 - val_loss: 3.6035 - val_top_k_categorical_accuracy: 0.0827 - learning_rate: 1.0000e-06
# Epoch 21/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 173ms/step - accuracy: 0.0328 - loss: 3.5297 - top_k_categorical_accuracy: 0.0939 - val_accuracy: 0.0331 - val_loss: 3.6033 - val_top_k_categorical_accuracy: 0.0790 - learning_rate: 1.0000e-06
# Epoch 22/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0312 - loss: 3.5280 - top_k_categorical_accuracy: 0.0859 - val_accuracy: 0.0294 - val_loss: 3.6065 - val_top_k_categorical_accuracy: 0.0882 - learning_rate: 1.0000e-06
# Epoch 23/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.0357 - loss: 3.5319 - top_k_categorical_accuracy: 0.0984 - val_accuracy: 0.0312 - val_loss: 3.6088 - val_top_k_categorical_accuracy: 0.0846 - learning_rate: 1.0000e-06
# Epoch 24/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0388 - loss: 3.5191 - top_k_categorical_accuracy: 0.0932 - val_accuracy: 0.0294 - val_loss: 3.6126 - val_top_k_categorical_accuracy: 0.0864 - learning_rate: 1.0000e-06
# Epoch 25/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0473 - loss: 3.5234 - top_k_categorical_accuracy: 0.1090 - val_accuracy: 0.0349 - val_loss: 3.6175 - val_top_k_categorical_accuracy: 0.0864 - learning_rate: 1.0000e-06
# Epoch 26/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 173ms/step - accuracy: 0.0302 - loss: 3.5269 - top_k_categorical_accuracy: 0.1023 - val_accuracy: 0.0331 - val_loss: 3.6195 - val_top_k_categorical_accuracy: 0.0790 - learning_rate: 1.0000e-06
# Epoch 27/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0331 - loss: 3.5279 - top_k_categorical_accuracy: 0.1050 - val_accuracy: 0.0294 - val_loss: 3.6222 - val_top_k_categorical_accuracy: 0.0827 - learning_rate: 1.0000e-06
# Epoch 28/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.0284 - loss: 3.5323 - top_k_categorical_accuracy: 0.0879 - val_accuracy: 0.0386 - val_loss: 3.6251 - val_top_k_categorical_accuracy: 0.0846 - learning_rate: 1.0000e-06
# Epoch 29/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 177ms/step - accuracy: 0.0267 - loss: 3.5310 - top_k_categorical_accuracy: 0.0956 - val_accuracy: 0.0294 - val_loss: 3.6296 - val_top_k_categorical_accuracy: 0.0772 - learning_rate: 1.0000e-06
# Epoch 30/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.0274 - loss: 3.5340 - top_k_categorical_accuracy: 0.0835 - val_accuracy: 0.0294 - val_loss: 3.6303 - val_top_k_categorical_accuracy: 0.0772 - learning_rate: 1.0000e-06
# Epoch 31/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0311 - loss: 3.5277 - top_k_categorical_accuracy: 0.0920 - val_accuracy: 0.0312 - val_loss: 3.6328 - val_top_k_categorical_accuracy: 0.0790 - learning_rate: 1.0000e-06
# Epoch 32/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 26s 185ms/step - accuracy: 0.0361 - loss: 3.5305 - top_k_categorical_accuracy: 0.1031 - val_accuracy: 0.0276 - val_loss: 3.6275 - val_top_k_categorical_accuracy: 0.0827 - learning_rate: 1.0000e-06
# Epoch 33/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 27s 187ms/step - accuracy: 0.0297 - loss: 3.5336 - top_k_categorical_accuracy: 0.0867 - val_accuracy: 0.0239 - val_loss: 3.6275 - val_top_k_categorical_accuracy: 0.0846 - learning_rate: 1.0000e-06
# Epoch 34/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 177ms/step - accuracy: 0.0340 - loss: 3.5332 - top_k_categorical_accuracy: 0.0783 - val_accuracy: 0.0312 - val_loss: 3.6286 - val_top_k_categorical_accuracy: 0.0809 - learning_rate: 1.0000e-06
# Epoch 35/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 176ms/step - accuracy: 0.0319 - loss: 3.5282 - top_k_categorical_accuracy: 0.0993 - val_accuracy: 0.0331 - val_loss: 3.6305 - val_top_k_categorical_accuracy: 0.0846 - learning_rate: 1.0000e-06
# Epoch 36/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0297 - loss: 3.5293 - top_k_categorical_accuracy: 0.1038 - val_accuracy: 0.0312 - val_loss: 3.6279 - val_top_k_categorical_accuracy: 0.0790 - learning_rate: 1.0000e-06
# Epoch 37/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 172ms/step - accuracy: 0.0354 - loss: 3.5267 - top_k_categorical_accuracy: 0.0978 - val_accuracy: 0.0349 - val_loss: 3.6268 - val_top_k_categorical_accuracy: 0.0754 - learning_rate: 1.0000e-06
# Epoch 38/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 175ms/step - accuracy: 0.0388 - loss: 3.5266 - top_k_categorical_accuracy: 0.1086 - val_accuracy: 0.0312 - val_loss: 3.6269 - val_top_k_categorical_accuracy: 0.0754 - learning_rate: 1.0000e-06
# Epoch 39/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 174ms/step - accuracy: 0.0313 - loss: 3.5252 - top_k_categorical_accuracy: 0.0947 - val_accuracy: 0.0331 - val_loss: 3.6277 - val_top_k_categorical_accuracy: 0.0790 - learning_rate: 1.0000e-06
# Epoch 40/40
# 136/136 ━━━━━━━━━━━━━━━━━━━━ 25s 173ms/step - accuracy: 0.0379 - loss: 3.5314 - top_k_categorical_accuracy: 0.0864 - val_accuracy: 0.0312 - val_loss: 3.6301 - val_top_k_categorical_accuracy: 0.0864 - learning_rate: 1.0000e-06
# ✅ Final MobileNetV2 model saved.
